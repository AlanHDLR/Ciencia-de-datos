# %%
pago_total = 0
cadena_horas_laboradas = input("Ingrese el número de horas laboradas en una semana: ")
cadena_tarifa_por_hora = input("Ingrese su tarifa de pago por hora: ")
# comience su código aquí:
try: 
    entero1 = int(cadena_horas_laboradas) 
    entero2 = int(cadena_tarifa_por_hora)
except:
    entero1 = -1
    entero2 = -1

if entero1 > 0 and entero2 > 0:
    cadena_horas_laboradas = float(cadena_horas_laboradas)
    cadena_tarifa_por_hora = float(cadena_tarifa_por_hora)

    if cadena_horas_laboradas <= 40:
        pago_total = cadena_horas_laboradas * cadena_tarifa_por_hora 
        print("Su pago es de: ", round(pago_total, 1))

    elif cadena_horas_laboradas > 40 and cadena_horas_laboradas <= 50:
        pago1 = 40 * cadena_tarifa_por_hora
        pago2 = (cadena_horas_laboradas - 40) * (cadena_tarifa_por_hora * 1.1)
        pago_total = pago1 + pago2
        print("Su pago es de: ", round(pago_total,1))

    elif cadena_horas_laboradas > 50: 
        pago3 = cadena_horas_laboradas - 40
        if pago3 > 10:
            pago1 = 40 * cadena_tarifa_por_hora
            pago9 = 10 * (cadena_tarifa_por_hora * 1.1)
            pago2 = pago3 - 10
            pago4 = pago2 *(cadena_tarifa_por_hora * 1.2)
            pago_total = pago1 + pago9 + pago4
            print("Su pago es de: ", round(pago_total, 1))
        else:
            pass
else:
    print("Parámetros incorrectos")
# Out:
# Ingrese el número de horas laboradas en una semana:  10
# Ingrese su tarifa de pago por hora:  -5
# Parámetros incorrectos

# %%
#else cadena_horas_laboradas > 50:
 #   print("Su pago es de: ", ((cadena_horas_laboradas * cadena_tarifa_por_hora) +((-50+cadena_horas_laboradas) * 1.2))
