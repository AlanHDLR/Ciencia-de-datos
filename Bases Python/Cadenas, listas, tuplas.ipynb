# %%
# Ejemplos de asignaciones 
x = 2
print(x)
# Out:
# 2

# %%
x = x + 3
print(x)
# Out:
# 5

# %%
# Potencia
y = x ** 2
print(y)
# Out:
# 25

# %%
# Residuo
z = 23 % 5
print(z)
# Out:
# 3

# %%
x= 1 + 2 + 3 *5 / 2

# %%
# Entender que sigue la jerarquia de operaciones 
print(x)
# Out:
# 10.5

# %%
y = 1 + 2 **3 / 4 * 5
print(y)
# Out:
# 11.0

# %%
# Se pueden usar parentesis para darlre un orden distinto a las operaciones 
w = (1 + 2) ** 3 / 4 * 5

# %%
print(w)
# Out:
# 33.75

# %%
# Nos muestra el tipo de dato que estamos usando
type(w)
# Out:
# float

# %%
texto = "Hola"
print(texto)
# Out:
# Hola

# %%
type(texto)
# Out:
# str

# %%
# Concatenación: Unir dos tipos de datos 
texto2 = "Hola " + "Buen día"
print(texto2)
# Out:
# Hola Buen día

# %%
texto2 = texto2 + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 texto2 = texto2 + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = 4
type(x)
# Out:
# int

# %%
x = 10
y = 15
z = x / y
type(z)
# Out:
# float

# %%
print(z)
# Out:
# 0.6666666666666666

# %%
z = int(z)
print(z)
# Out:
# 0

# %%
type(x)
# Out:
# int

# %%
x = float(x)
print(x)
# Out:
# 10.0

# %%
type(x)
# Out:
# float

# %%
nombre = input("¿Como te llamas?")
print("Tu nombre es: ", nombre)
# Out:
# ¿Como te llamas? Alan
# Tu nombre es:  Alan

# %%
# El input detecta el númeore como texto, no como un valor
# Par eso utilizamos un "int" al inicio de l avariable para convertirla a valor númerico
edad = input("Dame tu edad")
resultado = int(edad) * 2
print(resultado)
# Out:
# Dame tu edad 22
# 44
