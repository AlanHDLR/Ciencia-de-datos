# %% [markdown]
# # Palabras reservadas

# %%
print("Que tal!")
# Out:
# Que tal!

# %%
print("Bienvenido al curso de Python")
# Out:
# Bienvenido al curso de Python

# %% [markdown]
# # Sentencias

# %% [markdown]
# Linea de programa que se encarga de ejecutar una intrucciona a la vez

# %%
x = 10.5
y = 20

# %%
print(x)
# Out:
# 10.5

# %%
print("El valor de x es: ", x)
# Out:
# El valor de x es:  10.5

# %%
z = x+y

# %%
print("El resultado de z es: ", z)
# Out:
# El resultado de z es:  30.5

# %%
long_objeto1 = 10.5
long_objeto2 = 20
long_objeto3 = long_objeto1 + long_objeto2
print(long_objeto3)
# Out:
# 30.5

# %% [markdown]
# # Script

# %% [markdown]
# Un Script represneta un programa completo con una serie de enunciados.
# La extensión para un archivo resultante es ".py"
